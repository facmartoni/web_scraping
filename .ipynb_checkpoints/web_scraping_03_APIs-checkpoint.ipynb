# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{artist_id}'

# %%
id_im = '6mdiAmATAx73kdxrNrnlao'

# %%
url_base+ep_artist.format(artist_id=id_im)
# Out:
# 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao'

# %%
import requests

# %%
r = requests.get(url_base+ep_artist.format(artist_id=id_im))

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %%
headers = {'Authorization': 'Basic NWY1NjJjMjRhM2E5NDA4MWIyODRjNTY3OWFkOTliYzU6YjdlNzFlMjQ5NWRiNDM3YmFjMjlkOTYwMjVmYjgwMzI='}

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQDD_Nyda_-_l8N6apr0G2CB9rVlf74aNGJ58O_4gZ1nJ0FSOMJ1XTR2WFeECJRT5CEVtkk_Ynw20auLy9Y',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
token = r.json()['access_token']

# %%
header = {'Authorization': 'Bearer {token}'.format(token=token)}

# %%
r = requests.get(url_base+ep_artist.format(artist_id=id_im), headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#  'followers': {'href': None, 'total': 4856650},
#  'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#  'id': '6mdiAmATAx73kdxrNrnlao',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/9b47777582da7ee93a65c89d1d28688cc0e6225b',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/2f50e6730873b368928778b6507a682e6d1605af',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/c975d9b04dd8b53b3eb4a61b556743352127b399',
#    'width': 160}],
#  'name': 'Iron Maiden',
#  'popularity': 78,
#  'type': 'artist',
#  'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {
    'q': 'Iron-Maiden',
    'type': 'artist',
    'market': 'AR'
}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Iron-Maiden&type=artist&market=AR&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#     'followers': {'href': None, 'total': 4856650},
#     'genres': ['album rock', 'hard rock', 'metal', 'nwobhm', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#     'id': '6mdiAmATAx73kdxrNrnlao',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9b47777582da7ee93a65c89d1d28688cc0e6225b',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/2f50e6730873b368928778b6507a682e6d1605af',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/c975d9b04dd8b53b3eb4a61b556743352127b399',
#       'width': 160}],
#     'name': 'Iron Maiden',
#     'popularity': 78,
#     'type': 'artist',
#     'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VhddzEFAYbACFHu6K6btD'},
#     'followers': {'href': None, 'total': 962},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0VhddzEFAYbACFHu6K6btD',
#     'id': '0VhddzEFAYbACFHu6K6btD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e73c1fd8a62720ff999702d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e73c1fd8a62720ff999702d9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e73c1fd8a62720ff999702d9',
#       'width': 64}],
#     'name': 'Paul Dianno & Dennis Stratton from Iron Maiden',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:0VhddzEFAYbACFHu6K6btD'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5jtCtv88wno9jIusR82dmQ'},
#     'followers': {'href': None, 'total': 1846},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5jtCtv88wno9jIusR82dmQ',
#     'id': '5jtCtv88wno9jIusR82dmQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732b429488deb0d0e910acfe57',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022b429488deb0d0e910acfe57',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512b429488deb0d0e910acfe57',
#       'width': 64}],
#     'name': 'The Iron Maiden',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:5jtCtv88wno9jIusR82dmQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZr3Xthgy283qC7s4tVM1'},
#     'followers': {'href': None, 'total': 366},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2YZr3Xthgy283qC7s4tVM1',
#     'id': '2YZr3Xthgy283qC7s4tVM1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273518deb4f90339a9b753ee35e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02518deb4f90339a9b753ee35e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851518deb4f90339a9b753ee35e',
#       'width': 64}],
#     'name': 'The Bolton Iron Maiden',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZr3Xthgy283qC7s4tVM1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7p7Pae1Xc78SpEAknWJwWL'},
#     'followers': {'href': None, 'total': 593},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7p7Pae1Xc78SpEAknWJwWL',
#     'id': '7p7Pae1Xc78SpEAknWJwWL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273088329c27d6d4ec8466ef330',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02088329c27d6d4ec8466ef330',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851088329c27d6d4ec8466ef330',
#       'width': 64}],
#     'name': 'Iron Maidnem (tribute to Iron Maiden)',
#     'popularity': 14,
#     'type': 'artist',
#     'uri': 'spotify:artist:7p7Pae1Xc78SpEAknWJwWL'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4qsdtkjKjhxbFC4Bvtd26C'},
#     'followers': {'href': None, 'total': 117},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4qsdtkjKjhxbFC4Bvtd26C',
#     'id': '4qsdtkjKjhxbFC4Bvtd26C',
#     'images': [],
#     'name': 'Bruce Dickinson & Adrian Smith (IRON MAIDEN)',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4qsdtkjKjhxbFC4Bvtd26C'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 6}}

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])

# %%
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/0...
# 2  {'spotify': 'https://open.spotify.com/artist/5...
# 3  {'spotify': 'https://open.spotify.com/artist/2...
# 4  {'spotify': 'https://open.spotify.com/artist/7...
#
#                           followers  \
# 0  {'href': None, 'total': 4856650}
# 1      {'href': None, 'total': 962}
# 2     {'href': None, 'total': 1846}
# 3      {'href': None, 'total': 366}
# 4      {'href': None, 'total': 593}
#
#                                          genres  \
# 0  [album rock, hard rock, metal, nwobhm, rock]
# 1                                            []
# 2                                            []
# 3                                            []
# 4                                            []
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6mdiAmATAx7...  6mdiAmATAx73kdxrNrnlao
# 1  https://api.spotify.com/v1/artists/0VhddzEFAYb...  0VhddzEFAYbACFHu6K6btD
# 2  https://api.spotify.com/v1/artists/5jtCtv88wno...  5jtCtv88wno9jIusR82dmQ
# 3  https://api.spotify.com/v1/artists/2YZr3Xthgy2...  2YZr3Xthgy283qC7s4tVM1
# 4  https://api.spotify.com/v1/artists/7p7Pae1Xc78...  7p7Pae1Xc78SpEAknWJwWL
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                              name  popularity    type  \
# 0                                     Iron Maiden          78  artist
# 1  Paul Dianno & Dennis Stratton from Iron Maiden           7  artist
# 2                                 The Iron Maiden           7  artist
# 3                          The Bolton Iron Maiden           1  artist
# 4           Iron Maidnem (tribute to Iron Maiden)          14  artist
#
#                                      uri
# 0  spotify:artist:6mdiAmATAx73kdxrNrnlao
# 1  spotify:artist:0VhddzEFAYbACFHu6K6btD
# 2  spotify:artist:5jtCtv88wno9jIusR82dmQ
# 3  spotify:artist:2YZr3Xthgy283qC7s4tVM1
# 4  spotify:artist:7p7Pae1Xc78SpEAknWJwWL

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id + ':' + client_secret, 'utf-8'))
    params = {'grant_type': 'client_credentials'}
    header = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en la request:', r.json())
        return None
    print('Token válido por {} segundos'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = '5f562c24a3a94081b284c5679ad99bc5'

# %%
client_secret = 'b7e71e2495db437bac29d96025fb8032'

# %%
token = get_token(client_id, client_secret)
# Out:
# Tóken válido por 3600 segundos

# %%
token
# Out:
# 'BQB2s14Oq4V4f34RG-yzvq2_CBnfnVVrnEZvqoJCxCEQQbNsRaaJICxaXwgXTo_PHSDKGhZ5DYE1LL05K8k'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
id_im
# Out:
# '6mdiAmATAx73kdxrNrnlao'

# %%
ep_albums = '/artists/{artist_id}/albums'

# %%
url_base + ep_albums
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %%
paramas = {'country': 'AR'}

# %%
albums_im = requests.get(url_base + ep_albums.format(artist_id=id_im), headers=header, params=params)

# %%
albums_im.status_code
# Out:
# 200

# %%
albums_im.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#    'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#    'id': '6mdiAmATAx73kdxrNrnlao',
#    'name': 'Iron Maiden',
#    'type': 'artist',
#    'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#  'available_markets': ['AD',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IS',
#   'IT',
#   'JP',
#   'KW',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'RO',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TR',
#   'TW',
#   'UY',
#   'VN',
#   'ZA'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#  'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#  'id': '3oFAX7PeOFbZnKiPmpUPv4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#    'width': 64}],
#  'name': 'The Book of Souls: Live Chapter',
#  'release_date': '2017-11-17',
#  'release_date_precision': 'day',
#  'total_tracks': 15,
#  'type': 'album',
#  'uri': 'spotify:album:3oFAX7PeOFbZnKiPmpUPv4'}

# %%
album_id = '3oFAX7PeOFbZnKiPmpUPv4'

# %%
ep_album = '/albums/{album_id}'

# %%
def get_album_info(album_id, token):
    """Función que devuelve un objeto JSON con la información de un 
    álbum en específico"""
    
    header = {'Authorization': 'Bearer {}'.format(token)}
    paramas = {'country': 'AR'}
    album = requests.get(url_base + ep_album.format(album_id=album_id), headers=header, params=params)
    return album.json()

# %%
get_album_info(album_id, token)
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#    'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#    'id': '6mdiAmATAx73kdxrNrnlao',
#    'name': 'Iron Maiden',
#    'type': 'artist',
#    'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#  'available_markets': ['AD',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IS',
#   'IT',
#   'JP',
#   'KW',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'RO',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TR',
#   'TW',
#   'UY',
#   'VN',
#   'ZA'],
#  'copyrights': [{'text': '2017 Iron Maiden LLP under exclusive license to Parlophone Records Ltd, a Warner Music Group Company',
#    'type': 'C'},
#   {'text': '2017 Iron Maiden LLP under exclusive license to Parlophone Records Ltd, a Warner Music Group Company',
#    'type': 'P'}],
#  'external_ids': {'upc': '190295760861'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3oFAX7PeOFbZnKiPmpUPv4'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4',
#  'id': '3oFAX7PeOFbZnKiPmpUPv4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273f831658588b69a862c054861',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02f831658588b69a862c054861',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851f831658588b69a862c054861',
#    'width': 64}],
#  'label': 'Parlophone UK',
#  'name': 'The Book of Souls: Live Chapter',
#  'popularity': 49,
#  'release_date': '2017-11-17',
#  'release_date_precision': 'day',
#  'total_tracks': 15,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/3oFAX7PeOFbZnKiPmpUPv4/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 466573,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6aMCbBm6rx5FOn2UgICfOd'},
#     'href': 'https://api.spotify.com/v1/tracks/6aMCbBm6rx5FOn2UgICfOd',
#     'id': '6aMCbBm6rx5FOn2UgICfOd',
#     'is_local': False,
#     'name': 'If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/01806cb0121fe0a6af38d678ba0efe7353ad395c?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6aMCbBm6rx5FOn2UgICfOd'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 308853,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3qEVtE6ITRUuXMyxEP2zyx'},
#     'href': 'https://api.spotify.com/v1/tracks/3qEVtE6ITRUuXMyxEP2zyx',
#     'id': '3qEVtE6ITRUuXMyxEP2zyx',
#     'is_local': False,
#     'name': 'Speed of Light - Live at Grand Arena, GrandWest, Cape Town, South Africa, Wednesday, 5/18/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b59890db38d488b7262d515f422d35ecc4a38c3c?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3qEVtE6ITRUuXMyxEP2zyx'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 179973,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0N1VuzFPeVK7k9S7Bjq7LW'},
#     'href': 'https://api.spotify.com/v1/tracks/0N1VuzFPeVK7k9S7Bjq7LW',
#     'id': '0N1VuzFPeVK7k9S7Bjq7LW',
#     'is_local': False,
#     'name': 'Wrathchild - Live at 3 Arena, Dublin, Ireland, Saturday, 5/6/2017',
#     'preview_url': 'https://p.scdn.co/mp3-preview/8706205f28180ce71ca91191a1c64e76caa10ea2?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0N1VuzFPeVK7k9S7Bjq7LW'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 314520,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mCjzmxV8nPYNNHmzSHN0A'},
#     'href': 'https://api.spotify.com/v1/tracks/4mCjzmxV8nPYNNHmzSHN0A',
#     'id': '4mCjzmxV8nPYNNHmzSHN0A',
#     'is_local': False,
#     'name': 'Children of the Damned - Live at Bell Center, Montreal, Canada, Friday, 4/1/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/30cf878298494953cfb0dae4095812ab5a2a3789?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4mCjzmxV8nPYNNHmzSHN0A'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 315706,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4HB0T6PE3jx03spXKxt3Tk'},
#     'href': 'https://api.spotify.com/v1/tracks/4HB0T6PE3jx03spXKxt3Tk',
#     'id': '4HB0T6PE3jx03spXKxt3Tk',
#     'is_local': False,
#     'name': 'Death or Glory - Live at Wroclaw Stadium, Wroclaw, Poland, Sunday, 7/3/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/e0c65385b2a30ea2d94d26a0d629462915f70fa0?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4HB0T6PE3jx03spXKxt3Tk'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 797373,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1ijXUhEknFK1Wg6Dw9MUUd'},
#     'href': 'https://api.spotify.com/v1/tracks/1ijXUhEknFK1Wg6Dw9MUUd',
#     'id': '1ijXUhEknFK1Wg6Dw9MUUd',
#     'is_local': False,
#     'name': 'The Red and the Black - Live at Ryogoku Kokugikan, Tokyo, Japan, Thursday, 4/21/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/39f83f295768f96cf26bc59cf4e4875ed1995a47?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1ijXUhEknFK1Wg6Dw9MUUd'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245160,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6nmc8EQo7XzWRX3P8csvBi'},
#     'href': 'https://api.spotify.com/v1/tracks/6nmc8EQo7XzWRX3P8csvBi',
#     'id': '6nmc8EQo7XzWRX3P8csvBi',
#     'is_local': False,
#     'name': 'The Trooper - Live at Estadio Jorge Magico Gonzalez, San Salvador, El Salvador, Sunday, 3/6/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/3adee5cc172b5b987689c28803ad5859388c8a79?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6nmc8EQo7XzWRX3P8csvBi'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 451773,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2wqnxiwfUr5TqlJlPdM5WR'},
#     'href': 'https://api.spotify.com/v1/tracks/2wqnxiwfUr5TqlJlPdM5WR',
#     'id': '2wqnxiwfUr5TqlJlPdM5WR',
#     'is_local': False,
#     'name': "Powerslave - Live at Plaza Dell'Unita D'Italia, Trieste, Italy, Tuesday, 7/26/2016",
#     'preview_url': 'https://p.scdn.co/mp3-preview/a9fc213e160342b9c51f1adc331a68922c65082e?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2wqnxiwfUr5TqlJlPdM5WR'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 410400,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7hkAEQai7eBXVbaPqNXruC'},
#     'href': 'https://api.spotify.com/v1/tracks/7hkAEQai7eBXVbaPqNXruC',
#     'id': '7hkAEQai7eBXVbaPqNXruC',
#     'is_local': False,
#     'name': 'The Great Unknown - Live at MRA Arena, Newcastle, England, Sunday, 5/14/2017',
#     'preview_url': 'https://p.scdn.co/mp3-preview/736178ada363e6725ee5a11ea6c67f27b23740f3?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7hkAEQai7eBXVbaPqNXruC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 649613,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/18ql1wlPD1OJ1RnJpYxBQH'},
#     'href': 'https://api.spotify.com/v1/tracks/18ql1wlPD1OJ1RnJpYxBQH',
#     'id': '18ql1wlPD1OJ1RnJpYxBQH',
#     'is_local': False,
#     'name': 'The Book of Souls - Live at Download Festival, Donington, England, Sunday, 6/12/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/36f21d2287f0b64c1de77a2de5c93e31a8592a10?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:18ql1wlPD1OJ1RnJpYxBQH'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 454253,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3rO3egxxzdsGkgHgzpU6ri'},
#     'href': 'https://api.spotify.com/v1/tracks/3rO3egxxzdsGkgHgzpU6ri',
#     'id': '3rO3egxxzdsGkgHgzpU6ri',
#     'is_local': False,
#     'name': 'Fear of the Dark - Live at Arena Castelao, Fortaleza, Brazil, Thursday, 3/24/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/6f7c5948cf55a2498fb3571a325aaf984bf0fd10?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3rO3egxxzdsGkgHgzpU6ri'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 365293,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6zoso9hJPCPKnGrbBZB9QN'},
#     'href': 'https://api.spotify.com/v1/tracks/6zoso9hJPCPKnGrbBZB9QN',
#     'id': '6zoso9hJPCPKnGrbBZB9QN',
#     'is_local': False,
#     'name': 'Iron Maiden - Live at Estadio Velez Sarsfield, Buenos Aires, Argentina, Tuesday, 3/15/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/de31979b46583cd89ed9500140f5d78f121e4354?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6zoso9hJPCPKnGrbBZB9QN'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 306213,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4sWQLqhXoNSagfx3TEDHQf'},
#     'href': 'https://api.spotify.com/v1/tracks/4sWQLqhXoNSagfx3TEDHQf',
#     'id': '4sWQLqhXoNSagfx3TEDHQf',
#     'is_local': False,
#     'name': 'The Number of the Beast - Live at Open Air Festival, Wacken, Germany,Thursday, 8/4/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/fbd2c431681cce84e3d9f3a15d39909dd37ad28b?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4sWQLqhXoNSagfx3TEDHQf'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 455080,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Uwk2y1qvdEj5Xvyc6bAiR'},
#     'href': 'https://api.spotify.com/v1/tracks/0Uwk2y1qvdEj5Xvyc6bAiR',
#     'id': '0Uwk2y1qvdEj5Xvyc6bAiR',
#     'is_local': False,
#     'name': 'Blood Brothers - Live at Download Festival, Donington, England, Sunday, June, 12, 2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/87f21d260be675bd4feb1069b0edbbe28d8a7d4a?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0Uwk2y1qvdEj5Xvyc6bAiR'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 338546,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2hnJ1l71RzvHMYR9nuDpfE'},
#     'href': 'https://api.spotify.com/v1/tracks/2hnJ1l71RzvHMYR9nuDpfE',
#     'id': '2hnJ1l71RzvHMYR9nuDpfE',
#     'is_local': False,
#     'name': 'Wasted Years - Live at HSBC Arena, Rio De Janeiro, Brazil, Thursday, 3/17/2016',
#     'preview_url': 'https://p.scdn.co/mp3-preview/323f5e963b04549dfe26217275eb14e66381468c?cid=5f562c24a3a94081b284c5679ad99bc5',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:2hnJ1l71RzvHMYR9nuDpfE'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 15},
#  'type': 'album',
#  'uri': 'spotify:album:3oFAX7PeOFbZnKiPmpUPv4'}

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country = None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'Authorization': f'Bearer {token}'}
    params = {
        'limit': page_limit,
        'offset': 0,
        'country': country
    }
    lista = []
    r = requests.get(url, params=params, headers=header)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code == 200:
            if return_name:
                lista += [(item['id'], item['name']) for item in r.json()['items']]
            else:
                lista += [item['id'] for item in r.json()['items']]
        else:
            print('Error:', r.status_code, '\n', r.json())
    return lista

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {
        'limit': page_limit,
        'offset': 0,
        'market': market
    }
    lista = []
    r = requests.get(url, params=params, headers=header)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code == 200:
            if return_name:
                lista += [(item['id'], item['name']) for item in r.json()['items']]
            else:
                lista += [item['id'] for item in r.json()['items']]
        else:
            print('Error:', r.status_code, '\n', r.json())
    return lista

# %%
obtener_discografia(id_im, token, return_name = True)
# Out:
# [('3oFAX7PeOFbZnKiPmpUPv4', 'The Book of Souls: Live Chapter'),
#  ('0h63qX1zO0DAJLacVY3I7x', 'The Book of Souls: The Live Chapter'),
#  ('6QKC7ltfafdNeBZkzLdUvF', 'The Book of Souls'),
#  ('4vSfHrq6XxVyMcJ6PguFR2', 'The Book of Souls'),
#  ('44myoe2TKVeLrIhfcN7xVK', "Maiden England '88 (2013 Remaster)"),
#  ('3LymDdEISKszJqeN2z9DBI', 'En Vivo!'),
#  ('2hkRvIhUnPXbUbDDim63eJ', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1iPFLsjqez49QPCX9hPmIl', 'En Vivo! (Live at Estadio Nacional, Santiago)'),
#  ('1qwuDINuttWBKVx64FiOIj', 'The Final Frontier (2015 - Remaster)'),
#  ('5owI29GbshVBbC72drceUA', 'The Final Frontier (Deluxe Edition)'),
#  ('3CE0SB7URLI49lxJcykXUi', 'The Final Frontier'),
#  ('5YAfxU5OZKqAvE1GZPRQYY', 'The Final Frontier (2015 Remaster)'),
#  ('5nM0AuGFYzHeJSMxAkmLW9', 'Flight 666: The Original Soundtrack (Live)'),
#  ('3yTneaS0Z3xsAmCafaYjPw', 'Flight 666: The Original Soundtrack'),
#  ('1gdB9kn59KSAVG5VQcjdHi', 'A Matter of Life and Death (2015 Remaster)'),
#  ('6GfWgmPjUWdmjlR0qHWZj5', 'A Matter of Life and Death (2015 - Remaster)'),
#  ('2rVdAYBUuEnciOvQRrn4YL', 'Death on the Road'),
#  ('1kN3mPkY2Tg17XsbcVdiIb', 'Death on the Road'),
#  ('5ZtuSlGBItIKJVuk70plPc', 'Dance of Death (2015 - Remaster)'),
#  ('2Y8x0EEu7il0K2gCQIqVRh', 'Dance of Death (2015 Remaster)'),
#  ('7Fnx0dOtn0QL8nlSoCKkp9', 'Rock in Rio (Live; 2015 Remastered Version)'),
#  ('4SiZSq9igWhpJoMzjxE1xE', 'Rock In Rio [Live]'),
#  ('1nR4jUJsEkWlcu1bOPsWwr', 'Brave New World (2015 - Remaster)'),
#  ('1hDF0QPIHVTnSJtxyQVguB', 'Brave New World (2015 Remaster)'),
#  ('0axV6lvqshTCcGxT2AYiIK', 'Ed Hunter'),
#  ('5g3Kk70LJWtKSLUjPJjwNs', 'Virtual XI (2015 - Remaster)'),
#  ('4olc018Cln2QaMRFy1sk7v', 'Virtual XI (2015 Remaster)'),
#  ('59sh508ZnUfP5tozV8xfCS', 'The X Factor (2015 - Remaster)'),
#  ('3irqbaStVsDR9IEdg8Cdwz', 'The X Factor (2015 Remaster)'),
#  ('3DRvgymMVPG0TQ2DugHJRb', 'A Real Live Dead One (Live; 2006 Remaster)'),
#  ('5KuZGp07qx3sDzH1ygKJew', 'A Real Live Dead One'),
#  ('12vTiEGN96ZQtGb3zfpKE8', 'A Real Live One'),
#  ('77SZJrj0HAxMGvZtDzhvw7', 'Live at Donington (1998 Remaster)'),
#  ('66mnkzELAR3AK13W7Elv4l', 'Fear of the Dark (2015 - Remaster)'),
#  ('2oL2sDoViMPkZR3iP9cpGQ', 'Live at Donington (1998 Remaster)'),
#  ('16Su3EUFLPqWVyrwN1q5wO', 'Fear of the Dark (2015 Remaster)'),
#  ('21ZEAwY2TDnoQvVMJKkjUk', 'No Prayer for the Dying (2015 Remaster)'),
#  ('00uliTKAB5mqWzQKMYbrND', 'No Prayer for the Dying (2015 - Remaster)'),
#  ('4UWaqJplSqDf3hqlb0OdxR', 'Seventh Son of a Seventh Son (2015 - Remaster)'),
#  ('1suB0DNwLFtJijqR7Z0w0j', "Maiden England '88"),
#  ('1rG6IgNdwE1IGFuIKuYosz', 'Seventh Son of a Seventh Son (2015 Remaster)'),
#  ('2O3sMtk9Zy2RxocOURUFhr', 'Somewhere in Time (2015 - Remaster)'),
#  ('0OEg65hPhgP7B0Dy9TqP2L', 'Somewhere in Time (2015 Remaster)'),
#  ('2gA1cYJkNNA2cSctBHWqTP', 'Live After Death (1998 Remaster)'),
#  ('5jerDBRhUh7bfuSXW1Lfgt', 'Live After Death (1998 Remaster)'),
#  ('2HPWTaRPYl0Iu3lJrI5V2z', 'Powerslave (2015 - Remaster)'),
#  ('309KOMEivisMmBuzk09635', 'Powerslave (2015 Remaster)'),
#  ('6iVSpex7UohpwPOYZEYmvm', 'Piece of Mind (2015 - Remaster)'),
#  ('7I9Wh2IgvI3Nnr8Z1ZSWby', 'Piece of Mind (2015 Remaster)'),
#  ('33d72N71hl9bXwT4zAcqUy', 'The Number of the Beast (2015 - Remaster)'),
#  ('5S3gls8Kjn8KVmqlIDEBbO', 'The Number of the Beast (2015 Remaster)'),
#  ('0ICtvzBaaupE4LifaYbFAj', 'Killers (2015 - Remaster)'),
#  ('5REF2imQI3lMAmeWcDXE3D', 'Killers (2015 Remaster)'),
#  ('5nyyw7ThJdClJ0jPisOta3', 'Iron Maiden (2015 - Remaster)'),
#  ('3DNeMApEMCo4IDXNMYnlFi', 'Iron Maiden (2015 Remaster)'),
#  ('6gWeUs0erbyOKNUNdL0RM0',
#   'Speed of Light (Live at Grandwest Arena, Cape Town, South Africa, Wednesday, 5/18/2016)'),
#  ('1BkYFS0DfavcXgm6zLJNYd',
#   'Speed of Light (Live at Grandwest Arena, Cape Town, South Africa, Wednesday, 5/18/2016)'),
#  ('1DlcHL5gRBqtzQFos50Bzq', 'Speed of Light'),
#  ('3uoglieldzRbFPcuDiKNWG', 'Speed of Light'),
#  ('3ogsNtEAi6cGN3DrMI2o7O', 'From Fear to Eternity: The Best of 1990 - 2010'),
#  ('7Fu5RydhgnK4BfJI9I7DvN', 'From Fear to Eternity: The Best of 1990 - 2010'),
#  ('5mqfk3VEL40SCU7kpu0p6I', 'From Fear to Eternity: The Best of 1990 - 2010'),
#  ('42xya1i401AO3TkHo658Z0', 'From Fear to Eternity: The Best of 1990 - 2010'),
#  ('0SmIkzc7YgxqBV0V5RcbPt',
#   'Somewhere Back in Time (The Best of 1980 - 1989)'),
#  ('2BfXz1uwKCFaD5TddCWITq',
#   'Somewhere Back in Time (The Best of 1980 - 1989)'),
#  ('05097HLhJF3ZW4MnwxtlgZ', 'Metal Legends'),
#  ('44CGQx7846fhiUOwHmqBSp', 'Rock Out'),
#  ('77tGiHXduiUFZFdCPDa3H4', 'Mosh Pit Anthems'),
#  ('5igipuOqHtXBZCTI64HUsM', 'Legends of Metal'),
#  ('4CaL70rhiGyhQinTw7B3xu', 'Rock City'),
#  ('7BBvvem9IMItuOuFeVnrGF',
#   'Fighting With My Family (The Original Soundtrack)'),
#  ('5xcUBxPDxdQxu6BqogaZkp', 'Planet Rock'),
#  ('1sdsz8fZk56mhPdmlDfsTU', 'Playlist: Metal'),
#  ('4dBQIBuUm6627ZchOEJ9qh', 'Kerrang! Legends'),
#  ('4zuuHozfFsrQW1r2ml8DFn',
#   "Re-Machined: A Tribute To Deep Purple's Machine Head"),
#  ('3j0GDICh3MBA6P73CpVTWL', 'Rock Anthems'),
#  ('6SJXw6kXiRTxsFhOdqyWvh', 'Memoirs of a Broken Man')]

# %%
obtener_tracks(album_id, token, return_name = True)
# Out:
# [('6aMCbBm6rx5FOn2UgICfOd',
#   'If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016'),
#  ('3qEVtE6ITRUuXMyxEP2zyx',
#   'Speed of Light - Live at Grand Arena, GrandWest, Cape Town, South Africa, Wednesday, 5/18/2016'),
#  ('0N1VuzFPeVK7k9S7Bjq7LW',
#   'Wrathchild - Live at 3 Arena, Dublin, Ireland, Saturday, 5/6/2017'),
#  ('4mCjzmxV8nPYNNHmzSHN0A',
#   'Children of the Damned - Live at Bell Center, Montreal, Canada, Friday, 4/1/2016'),
#  ('4HB0T6PE3jx03spXKxt3Tk',
#   'Death or Glory - Live at Wroclaw Stadium, Wroclaw, Poland, Sunday, 7/3/2016'),
#  ('1ijXUhEknFK1Wg6Dw9MUUd',
#   'The Red and the Black - Live at Ryogoku Kokugikan, Tokyo, Japan, Thursday, 4/21/2016'),
#  ('6nmc8EQo7XzWRX3P8csvBi',
#   'The Trooper - Live at Estadio Jorge Magico Gonzalez, San Salvador, El Salvador, Sunday, 3/6/2016'),
#  ('2wqnxiwfUr5TqlJlPdM5WR',
#   "Powerslave - Live at Plaza Dell'Unita D'Italia, Trieste, Italy, Tuesday, 7/26/2016"),
#  ('7hkAEQai7eBXVbaPqNXruC',
#   'The Great Unknown - Live at MRA Arena, Newcastle, England, Sunday, 5/14/2017'),
#  ('18ql1wlPD1OJ1RnJpYxBQH',
#   'The Book of Souls - Live at Download Festival, Donington, England, Sunday, 6/12/2016'),
#  ('3rO3egxxzdsGkgHgzpU6ri',
#   'Fear of the Dark - Live at Arena Castelao, Fortaleza, Brazil, Thursday, 3/24/2016'),
#  ('6zoso9hJPCPKnGrbBZB9QN',
#   'Iron Maiden - Live at Estadio Velez Sarsfield, Buenos Aires, Argentina, Tuesday, 3/15/2016'),
#  ('4sWQLqhXoNSagfx3TEDHQf',
#   'The Number of the Beast - Live at Open Air Festival, Wacken, Germany,Thursday, 8/4/2016'),
#  ('0Uwk2y1qvdEj5Xvyc6bAiR',
#   'Blood Brothers - Live at Download Festival, Donington, England, Sunday, June, 12, 2016'),
#  ('2hnJ1l71RzvHMYR9nuDpfE',
#   'Wasted Years - Live at HSBC Arena, Rio De Janeiro, Brazil, Thursday, 3/17/2016')]

# %%
for album in obtener_discografia(id_im, token, return_name=True, country='AR'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name=True, market='AR'):
        print('\t', track[1])
# Out:
# The Book of Souls: Live Chapter
# 	 If Eternity Should Fail - Live at Qudos Bank Arena, Sydney, Australia, Friday, 5/6/2016
# 	 Speed of Light - Live at Grand Arena, GrandWest, Cape Town, South Africa, Wednesday, 5/18/2016
# 	 Wrathchild - Live at 3 Arena, Dublin, Ireland, Saturday, 5/6/2017
# 	 Children of the Damned - Live at Bell Center, Montreal, Canada, Friday, 4/1/2016
# 	 Death or Glory - Live at Wroclaw Stadium, Wroclaw, Poland, Sunday, 7/3/2016
# 	 The Red and the Black - Live at Ryogoku Kokugikan, Tokyo, Japan, Thursday, 4/21/2016
# 	 The Trooper - Live at Estadio Jorge Magico Gonzalez, San Salvador, El Salvador, Sunday, 3/6/2016
# 	 Powerslave - Live at Plaza Dell'Unita D'Italia, Trieste, Italy, Tuesday, 7/26/2016
# 	 The Great Unknown - Live at MRA Arena, Newcastle, England, Sunday, 5/14/2017
# 	 The Book of Souls - Live at Download Festival, Donington, England, Sunday, 6/12/2016
# 	 Fear of the Dark - Live at Arena Castelao, Fortaleza, Brazil, Thursday, 3/24/2016
# 	 Iron Maiden - Live at Estadio Velez Sarsfield, Buenos Aires, Argentina, Tuesday, 3/15/2016
# 	 The Number of the Beast - Live at Open Air Festival, Wacken, Germany,Thursday, 8/4/2016
# 	 Blood Brothers - Live at Download Festival, Donington, England, Sunday, June, 12, 2016
# 	 Wasted Years - Live at HSBC Arena, Rio De Janeiro, Brazil, Thursday, 3/17/2016
# The Book of Souls
# 	 If Eternity Should Fail
# 	 Speed of Light
# 	 The Great Unknown
# 	 The Red and the Black
# 	 When the River Runs Deep
# 	 The Book of Souls
# 	 Death or Glory
# 	 Shadows of the Valley
# 	 Tears of a Clown
# 	 The Man of Sorrows
# 	 Empire of the Clouds
# Maiden England '88 (2013 Remaster)
# 	 Moonchild - Live at Birmingham NEC, 1988; 2013 Remaster
# 	 The Evil That Men Do - Live at Birmingham NEC, 1988; 2013 Remaster
# 	 The Prisoner - Live at Birmingham NEC, 1988; 2013 Remaster
# 	 Still Life - Live at Birmingham NEC, 1988; 2013 Remaster
# 	 Die with Your Boots On - Live Birmingham NEC, 1988; 2013 Remaster
# 	 Infinite Dreams - Live at Birmingham NEC, 1988; 2013 Remaster
# 	 